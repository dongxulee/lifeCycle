# %%
# %pylab inline
from helpFunctions import surfacePlot
import numpy as np
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
Vgrid_i = np.load("Vgrid_i.npy")
cgrid_i = np.load("cgrid_i.npy" )
bgrid_i = np.load("bgrid_i.npy" )
kgrid_i = np.load("kgrid_i.npy" )
igrid_i = np.load("igrid_i.npy" )
qgrid_i = np.load("qgrid_i.npy" )

# %%
plt.plot(cgrid_i[4,3,2,2,1,1,:69])

# %%
plt.plot(bgrid_i[4,3,2,2,1,1,:69])

# %%
plt.plot(kgrid_i[4,3,2,2,1,1,:69])

# %%
plt.plot(igrid_i[4,3,2,2,1,1,:69])

# %%
plt.plot(qgrid_i[4,3,2,2,1,1,:69])

# %%
Vgrid_k = np.load("Vgrid_k.npy")
cgrid_k = np.load("cgrid_k.npy" )
bgrid_k = np.load("bgrid_k.npy" )
kgrid_k = np.load("kgrid_k.npy" )
igrid_k = np.load("igrid_k.npy" )
qgrid_k = np.load("qgrid_k.npy" )

# %%
plt.plot(cgrid_k[4,3,2,2,1,1,:69])

# %%
plt.plot(bgrid_k[4,3,2,2,1,1,:69])

# %%
plt.plot(kgrid_k[4,3,2,2,1,1,:69])

# %%
plt.plot(igrid_k[4,3,2,2,1,1,:69])

# %%
plt.plot(qgrid_k[4,3,2,2,1,1,:69])
