# %%
# %pylab inline
import numpy as np
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
detEarning = np.load("detEarningHigh.npy")
plt.plot(detEarning, label = "normal")
plt.plot(shiftEarning, label = "shift")
plt.legend()

# %%
shiftEarning = np.concatenate((np.linspace(50, 100, 35), np.linspace(100, 80, 8)[1:], np.linspace(80, 50, 6)[1:], [50]*24))

# %%
np.save("shiftEarning",shiftEarning)
