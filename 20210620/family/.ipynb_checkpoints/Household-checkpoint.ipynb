# %%
# %pylab inline
matplotlib.rcParams['figure.figsize'] = [16, 8]
plt.rcParams.update({'font.size': 30})
import pandas as pd
pd.options.display.float_format = "{:.2f}".format
import numpy as np
import warnings
from tqdm import tqdm
warnings.filterwarnings("ignore")
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# All variables we care about
FcolumnNames1999_2007 = ['releaseNum', 'familyID', 'composition', 'headCount', 'ageHead', 'maritalStatus', 'own', 
                         'employmentStatus', 'liquidWealth', 'race', 'industry','incomeHead', "incomeWife", 
               'foodCost', 'houseCost', 'transCost', 'educationCost', 'childCost', 'healthCost', 'education', 
               'participation', 'investmentAmount', 'annuityIRA', 'wealthWithoutHomeEquity', "wealthWithHomeEquity"]

FcolumnNames2009_2017 = ['releaseNum', 'familyID', 'composition', 'headCount', 'ageHead', 'maritalStatus', 'own', 
                         'employmentStatus', 'liquidWealth', 'race', 'industry' ,'incomeHead', 'incomeWife', 
               'participation', 'investmentAmount', 'annuityIRA', 'wealthWithoutHomeEquity', 'wealthWithHomeEquity',
               'foodCost', 'houseCost', 'transCost', 'educationCost', 'childCost', 'healthCost', 'education']


# The timeline we care about
years = [1999, 2001, 2003, 2005, 2007, 2009, 2011, 2013, 2015, 2017]

# %%
def Fcompile_data_with_features(features, years = years):
    df = pd.DataFrame()
    # Loading the data through years
    for year in years:
        df_sub = pd.read_excel(str(year) + ".xlsx")
        if year >= 1999 and year <= 2007:
            df_sub.columns = FcolumnNames1999_2007
        else:
            df_sub.columns = FcolumnNames2009_2017
        df_sub['year'] = year
        df = pd.concat([df, df_sub[['familyID','year'] + features]])
    df = df.reset_index(drop = True)
    return df

# The function is used to drop the values we do not like in the dataFrame, 
# the input "features" and "values" are both list
def drop_values(features, values, df): 
    for feature in features:
        for value in values:
            df = df[df[feature] != value]
    df = df.reset_index(drop = True)
    return df

# %%
# prepare the combined dataset and set up dummy variables for qualitative data
df = Fcompile_data_with_features(['composition', 'headCount', 'ageHead', 'maritalStatus', 'own', 
                                  'employmentStatus', 'liquidWealth', 'race', 'industry','incomeHead', "incomeWife", 
                                  'foodCost', 'houseCost', 'transCost', 'educationCost', 'childCost', 'healthCost', 'education', 
                                  'participation', 'investmentAmount', 'annuityIRA', 'wealthWithoutHomeEquity', 'wealthWithHomeEquity'], years)

# %%
# data clean, drop NA/DK values
df = drop_values(["ageHead"],[999], df)
df = drop_values(["maritalStatus"],[8,9], df)
df = drop_values(["own"],[8,9], df)
df = drop_values(["employmentStatus"],[0,22,8,98, 99], df)
df = drop_values(["liquidWealth"],[999999998,999999999,-400], df)
df = drop_values(["race"],[0,8,9], df)
df = drop_values(["industry"],[999,9999,0], df)
df = drop_values(["education"],[99,0], df)
# calculate the aggregate variables 
df["totalExpense"] = df[['foodCost', 'houseCost', 'transCost', 
                                      'educationCost', 'childCost', 'healthCost']].sum(axis = 1)
df["laborIncome"] = df["incomeHead"] + df["incomeWife"]
df["costPerPerson"] = df["totalExpense"]/df["headCount"]
df["HomeEquity"] = df["wealthWithHomeEquity"] - df["wealthWithoutHomeEquity"]

# %%
maritalStatus = ["Married", "neverMarried", "Widowed", "Divorced", "Separated"]
employmentStatus = ["Working", "temporalLeave", "unemployed", "retired", "disabled", "keepHouse", "student", "other"]
race = ["White", "Black","AmericanIndian","Asian","Latino","otherBW","otherRace"]
# Education
# < 8th grade: middle school
# >= 8 and < 12: high scho0l
# >=12 and < 15: college
# >= 15 post graduate
education = ["middleSchool", "highSchool", "college", "postGraduate"]
# Industry
# < 400 manufacturing
# >= 400 and < 500 publicUtility
# >= 500 and < 680 retail 
# >= 680 and < 720 finance
# >= 720 and < 900 service
# >= 900 otherIndustry
industry = ["finance", "noneFinance"]
ownership = ["owner", "renter"]

data = []
for i in tqdm(range(len(df))):
    dataCollect = []
    # marital status
    dataCollect.append(maritalStatus[int(df.iloc[i]["maritalStatus"]-1)])
    # employment
    dataCollect.append(employmentStatus[int(df.iloc[i]["employmentStatus"]-1)])
    # race
    dataCollect.append(race[int(df.iloc[i]["race"] - 1)])
    # Education variable 
    if df.iloc[i]["education"] < 8:
        dataCollect.append(education[0])
    elif df.iloc[i]["education"] >= 8 and df.iloc[i]["education"] < 12:
        dataCollect.append(education[1])
    elif df.iloc[i]["education"] >= 12 and df.iloc[i]["education"] < 15:
        dataCollect.append(education[2])
    else:
        dataCollect.append(education[3])
    # industry variable 
    if df.iloc[i]["year"] in [1999, 2001]:
        if df.iloc[i]["industry"] >= 707 and df.iloc[i]["industry"] <= 718:
            dataCollect.append(industry[0])
        else:
            dataCollect.append(industry[1])
    elif df.iloc[i]["year"] in [2003,2005,2007,2009,2011,2013,2015,2015]:
        if df.iloc[i]["industry"] >= 687 and df.iloc[i]["industry"] <= 699:
            dataCollect.append(industry[0])
        else:
            dataCollect.append(industry[1])        
    else:
        if df.iloc[i]["industry"] >= 6870 and df.iloc[i]["industry"] <= 6990:
            dataCollect.append(industry[0])
        else:
            dataCollect.append(industry[1])
    # ownership status 
    if df.iloc[i]["own"] == 1:
        dataCollect.append(ownership[0])
    else:
        dataCollect.append(ownership[1])
    data.append(dataCollect)
# Categorical dataFrame
df_cat = pd.DataFrame(data, columns = ["maritalStatus", "employmentStatus", "race", "education", "industry", "ownership"])

# %%
Fdf = pd.concat([df[["familyID", "year",'composition', 'headCount', 'ageHead', 'liquidWealth', 'laborIncome', 
                     "costPerPerson","totalExpense", 'participation', 'investmentAmount', 'annuityIRA', 
                                 'wealthWithoutHomeEquity', "wealthWithHomeEquity", "HomeEquity"]], 
                          df_cat[["maritalStatus", "employmentStatus", "education","race", "industry", "ownership"]]], axis=1)
Fdf.head()
# Out:
#    familyID  year  composition  headCount  ageHead  liquidWealth  laborIncome  \
# 0         3  1999            2          1       76          2000            0
# 1         2  1999            0          4       47             0        22260
# 2      6129  1999            3          1       45          7500            0
# 3      6944  1999            0          2       39         12000        30000
# 4      3818  1999            4          4       34             0        41600
#
#    costPerPerson  totalExpense  participation  ...  annuityIRA  \
# 0        6213.62       6213.62              0  ...           0
# 1        3551.50      14206.00              1  ...           0
# 2       14223.65      14223.65              1  ...       17000
# 3        8762.18      17524.36              0  ...           0
# 4        3790.50      15162.00              0  ...           0
#
#    wealthWithoutHomeEquity  wealthWithHomeEquity  HomeEquity  maritalStatus  \
# 0                    31500                 91500       60000        Widowed
# 1                    20000                 26000        6000        Married
# 2                   381500                413500       32000       Divorced
# 3                    27000                 42000       15000       Divorced
# 4                    12000                 20000        8000        Married
#
#   employmentStatus     education   race     industry ownership
# 0          retired  middleSchool  White  noneFinance     owner
# 1          Working    highSchool  White  noneFinance     owner
# 2          Working       college  White      finance     owner
# 3          Working       college  White  noneFinance     owner
# 4          Working    highSchool  White  noneFinance     owner
#
# [5 rows x 21 columns]

# %%
# Adjust for inflation, all values are in thousand dollor
years = [1999, 2001, 2003, 2005, 2007, 2009, 2011, 2013, 2015, 2017]
values_at2020 = np.array([1.55, 1.46, 1.40, 1.32, 1.24, 1.20, 1.15, 1.11, 1.09, 1.05])
values_at2005 = values_at2020/1.32
values_at2005
quantVariables = ['annuityIRA', 'investmentAmount', 'liquidWealth', 'laborIncome', 'costPerPerson',
                 'totalExpense', 'wealthWithoutHomeEquity', 'wealthWithHomeEquity', "HomeEquity"]
for i in tqdm(range(len(Fdf))):
    for variable in quantVariables:
        Fdf.loc[i, variable] = round(Fdf.loc[i, variable] * values_at2005[years.index(Fdf.loc[i,"year"])] / 1000, 2)
Fdf.head()
# Out:
#    familyID  year  composition  headCount  ageHead  liquidWealth  laborIncome  \
# 0         3  1999            2          1       76          2.35         0.00
# 1         2  1999            0          4       47          0.00        26.14
# 2      6129  1999            3          1       45          8.81         0.00
# 3      6944  1999            0          2       39         14.09        35.23
# 4      3818  1999            4          4       34          0.00        48.85
#
#    costPerPerson  totalExpense  participation  ...  annuityIRA  \
# 0           7.30          7.30              0  ...        0.00
# 1           4.17         16.68              1  ...        0.00
# 2          16.70         16.70              1  ...       19.96
# 3          10.29         20.58              0  ...        0.00
# 4           4.45         17.80              0  ...        0.00
#
#    wealthWithoutHomeEquity  wealthWithHomeEquity  HomeEquity  maritalStatus  \
# 0                    36.99                107.44       70.45        Widowed
# 1                    23.48                 30.53        7.05        Married
# 2                   447.97                485.55       37.58       Divorced
# 3                    31.70                 49.32       17.61       Divorced
# 4                    14.09                 23.48        9.39        Married
#
#   employmentStatus     education   race     industry ownership
# 0          retired  middleSchool  White  noneFinance     owner
# 1          Working    highSchool  White  noneFinance     owner
# 2          Working       college  White      finance     owner
# 3          Working       college  White  noneFinance     owner
# 4          Working    highSchool  White  noneFinance     owner
#
# [5 rows x 21 columns]

# %%
# drop the outliers 
for var in quantVariables:
    Fdf = Fdf[Fdf[var] < Fdf[var].quantile(0.995)]
Fdf = Fdf[(Fdf["ageHead"] >= 20) & (Fdf["ageHead"] <= 80)]
Fdf.head()
# Out:
#    familyID  year  composition  headCount  ageHead  liquidWealth  laborIncome  \
# 0         3  1999            2          1       76          2.35         0.00
# 1         2  1999            0          4       47          0.00        26.14
# 2      6129  1999            3          1       45          8.81         0.00
# 3      6944  1999            0          2       39         14.09        35.23
# 4      3818  1999            4          4       34          0.00        48.85
#
#    costPerPerson  totalExpense  participation  ...  maritalStatus  \
# 0           7.30          7.30              0  ...        Widowed
# 1           4.17         16.68              1  ...        Married
# 2          16.70         16.70              1  ...       Divorced
# 3          10.29         20.58              0  ...       Divorced
# 4           4.45         17.80              0  ...        Married
#
#    employmentStatus     education   race     industry ownership skillLevel  \
# 0           retired  middleSchool  White  noneFinance     owner        Low
# 1           Working    highSchool  White  noneFinance     owner        Low
# 2           Working       college  White      finance     owner       High
# 3           Working       college  White  noneFinance     owner       High
# 4           Working    highSchool  White  noneFinance     owner        Low
#
#   financeExperience ageGroup decadeGroup
# 0                No       60       1990s
# 1                No       40       1990s
# 2               Yes       40       1990s
# 3                No       20       1990s
# 4                No       20       1990s
#
# [5 rows x 25 columns]

# %%
Fdf.shape
# Out:
# (55428, 25)

# %%
lowSkill = ["middleSchool", "highSchool"]
highSkill = ["college", "postGraduate"]
highFinance = Fdf[(Fdf["education"].isin(highSkill)) & (Fdf["industry"] == "finance")]
lowFinance = Fdf[(Fdf["education"].isin(lowSkill)) & (Fdf["industry"] == "finance")]
highNoneFinance = Fdf[(Fdf["education"].isin(highSkill)) & (Fdf["industry"] == "noneFinance")]
lowNoneFinance = Fdf[(Fdf["education"].isin(lowSkill)) & (Fdf["industry"] == "noneFinance")]

# %%
Fdf["skillLevel"] = "High"
Fdf.loc[Fdf["education"].isin(lowSkill), "skillLevel"] = "Low"
Fdf["financeExperience"] = "No"
Fdf.loc[Fdf["industry"] == "finance", "financeExperience"] = "Yes"
Fdf["ageGroup"] = "20"
Fdf["decadeGroup"] = "90's"
for i in range(2,10, 2):
    Fdf.loc[Fdf["ageHead"] > i*10, "ageGroup"] = str(i*10)
    
for year in range(1990,2020,10):
    Fdf.loc[Fdf["year"] > year, "decadeGroup"] = str(year) + "s"

# %%
Fdf.loc[(Fdf["employmentStatus"] != "Working")&(Fdf["employmentStatus"] != "retired"), "employmentStatus"] = "unemployed"
Fdf.loc[Fdf["employmentStatus"]=="Working", "employmentStatus"] = "employed"

# %%
Fdf.loc[Fdf["ageGroup"]== "20", "ageGroup"] = "20-40"
Fdf.loc[Fdf["ageGroup"]== "40", "ageGroup"] = "40-60"
Fdf.loc[Fdf["ageGroup"]== "60", "ageGroup"] = "60-80"

# %%
Fdf.head()
# Out:
#    familyID  year  composition  headCount  ageHead  liquidWealth  laborIncome  \
# 0         3  1999            2          1       76          2.35         0.00
# 1         2  1999            0          4       47          0.00        26.14
# 2      6129  1999            3          1       45          8.81         0.00
# 3      6944  1999            0          2       39         14.09        35.23
# 4      3818  1999            4          4       34          0.00        48.85
#
#    costPerPerson  totalExpense  participation  ...  maritalStatus  \
# 0           7.30          7.30              0  ...        Widowed
# 1           4.17         16.68              1  ...        Married
# 2          16.70         16.70              1  ...       Divorced
# 3          10.29         20.58              0  ...       Divorced
# 4           4.45         17.80              0  ...        Married
#
#    employmentStatus   education   race     industry ownership skillLevel  \
# 0           retired  highSchool  White  noneFinance     owner        Low
# 1          employed  highSchool  White  noneFinance     owner        Low
# 2          employed     college  White      finance     owner       High
# 3          employed     college  White  noneFinance     owner       High
# 4          employed  highSchool  White  noneFinance     owner        Low
#
#   financeExperience ageGroup decadeGroup
# 0                No       60       1990s
# 1                No    40-60       1990s
# 2               Yes    40-60       1990s
# 3                No    20-40       1990s
# 4                No    20-40       1990s
#
# [5 rows x 25 columns]

# %%
Fdf.tail()
# Out:
#        familyID  year  composition  headCount  ageHead  liquidWealth  \
# 62555      9074  2017            2          2       26          1.59
# 62556      4245  2017            0          1       59          0.00
# 62557      8251  2017            1          2       55          0.00
# 62558      8040  2017            0          2       29          0.80
# 62559      5120  2017            0          4       37          4.77
#
#        laborIncome  costPerPerson  totalExpense  participation  ...  \
# 62555        35.80          21.95         43.91              0  ...
# 62556         1.11           8.65          8.65              0  ...
# 62557        51.70          13.61         27.22              0  ...
# 62558        12.73          13.39         26.78              0  ...
# 62559        97.05          13.01         52.06              0  ...
#
#        maritalStatus  employmentStatus  education   race     industry  \
# 62555   neverMarried           Working    college  Black  noneFinance
# 62556       Divorced           Working    college  Black  noneFinance
# 62557        Married           Working    college  Black  noneFinance
# 62558   neverMarried        unemployed    college  Black  noneFinance
# 62559        Married           Working    college  Black  noneFinance
#
#       ownership skillLevel financeExperience ageGroup decadeGroup
# 62555    renter       High                No       20       2010s
# 62556    renter       High                No       40       2010s
# 62557     owner       High                No       40       2010s
# 62558    renter       High                No       20       2010s
# 62559     owner       High                No       20       2010s
#
# [5 rows x 25 columns]

# %%
Fdf[(Fdf["ownership"] == "renter") & (Fdf["HomeEquity"] != 0)]
# Out:
#        familyID  year  composition  headCount  ageHead  liquidWealth  \
# 1094        862  1999            0          1       24          1.17
# 23485      6067  2007            1          2       38          0.00
# 24066      7122  2007            0          3       54          1.88
# 24432      4879  2007            0          1       48         70.45
# 25032      4503  2007            0          1       63        232.97
#
#        laborIncome  costPerPerson  totalExpense  participation  ...  \
# 1094          7.75          20.06         20.06              0  ...
# 23485         1.88           8.82         17.64              0  ...
# 24066        49.22          13.75         41.26              0  ...
# 24432         0.00          43.37         43.37              0  ...
# 25032        17.33          32.20         32.20              1  ...
#
#        maritalStatus  employmentStatus     education   race     industry  \
# 1094    neverMarried           Working       college  White  noneFinance
# 23485       Divorced        unemployed       college  White  noneFinance
# 24066        Married           Working  postGraduate  White  noneFinance
# 24432       Divorced           Working  postGraduate  White  noneFinance
# 25032       Divorced           Working       college  White  noneFinance
#
#       ownership skillLevel financeExperience ageGroup decadeGroup
# 1094     renter       High                No       20       1990s
# 23485    renter       High                No       20       2000s
# 24066    renter       High                No       40       2000s
# 24432    renter       High                No       40       2000s
# 25032    renter       High                No       60       2000s
#
# [5 rows x 25 columns]

# %%
# participation
print(Fdf.groupby(["industry"])["participation"].describe())
print(Fdf.groupby(["skillLevel"])["participation"].describe())
# Out:
#                count  mean  std  min  25%  50%  75%  max
# industry
# finance      1517.00  0.24 0.42 0.00 0.00 0.00 0.00 1.00
# noneFinance 53911.00  0.13 0.34 0.00 0.00 0.00 0.00 1.00
#               count  mean  std  min  25%  50%  75%  max
# skillLevel
# High       45868.00  0.16 0.36 0.00 0.00 0.00 0.00 1.00
# Low         9560.00  0.04 0.19 0.00 0.00 0.00 0.00 1.00

# %%
def latexSummaryTable(var):

# %%
dddf = Fdf[Fdf["participation"] == 1].groupby(["industry"])["investmentAmount"].describe()[["count","mean", "std", "50%", "25%", "75%"]]

# %%
print(dddf.to_latex())
# Out:
# \begin{tabular}{lrrrrrr}
# \toprule
# {} &   count &  mean &   std &   50\% &  25\% &   75\% \\
# industry    &         &       &       &       &      &       \\
# \midrule
# finance     &  357.00 & 51.24 & 73.97 & 21.21 & 4.55 & 67.27 \\
# noneFinance & 7169.00 & 51.94 & 78.33 & 18.18 & 4.42 & 63.07 \\
# \bottomrule
# \end{tabular}

# %%
# investment amount | participation
dddf =Fdf[Fdf["participation"] == 1].groupby(["ageGroup","industry"])["investmentAmount"].describe()[["count","mean", "std", "50%", "25%", "75%"]]
dddf
# Out:
#                        count   mean    std   50%   25%    75%
# ageGroup industry
# 20-40    finance      164.00  24.64  34.46 10.33  3.31  28.84
#          noneFinance 2581.00  29.12  53.55  8.71  2.27  29.62
# 40-60    finance      128.00  57.58  69.82 40.00  9.10  66.14
#          noneFinance 3086.00  53.07  76.06 22.12  5.53  64.12
# 60-80    finance       65.00 105.88 113.20 81.82  9.55 154.85
#          noneFinance 1502.00  88.86 101.11 50.00 11.11 127.27

# %%
print(dddf.to_latex())
# Out:
# \begin{tabular}{llrrrrrr}
# \toprule
#       &             &   count &   mean &    std &   50\% &   25\% &    75\% \\
# ageGroup & industry &         &        &        &       &       &        \\
# \midrule
# 20-40 & finance &  164.00 &  24.64 &  34.46 & 10.33 &  3.31 &  28.84 \\
#       & noneFinance & 2581.00 &  29.12 &  53.55 &  8.71 &  2.27 &  29.62 \\
# 40-60 & finance &  128.00 &  57.58 &  69.82 & 40.00 &  9.10 &  66.14 \\
#       & noneFinance & 3086.00 &  53.07 &  76.06 & 22.12 &  5.53 &  64.12 \\
# 60-80 & finance &   65.00 & 105.88 & 113.20 & 81.82 &  9.55 & 154.85 \\
#       & noneFinance & 1502.00 &  88.86 & 101.11 & 50.00 & 11.11 & 127.27 \\
# \bottomrule
# \end{tabular}

# %%
dddf = Fdf.groupby(["industry"])["investmentAmount"].describe()[["count","mean", "std", "50%", "25%", "75%"]]
dddf
# Out:
#                count  mean   std  50%  25%  75%
# industry
# finance      1517.00 12.06 41.93 0.00 0.00 0.00
# noneFinance 53911.00  6.91 33.57 0.00 0.00 0.00

# %%
dddf = Fdf[Fdf["participation"] == 1].groupby(["skillLevel"])["investmentAmount"].describe()[["count","mean", "std", "50%", "25%", "75%"]]
print(dddf.to_latex())
# Out:
# \begin{tabular}{lrrrrrr}
# \toprule
# {} &   count &  mean &   std &   50\% &  25\% &   75\% \\
# skillLevel &         &       &       &       &      &       \\
# \midrule
# High       & 7165.00 & 51.91 & 77.78 & 18.18 & 4.42 & 63.64 \\
# Low        &  361.00 & 51.88 & 84.80 & 16.59 & 3.48 & 50.91 \\
# \bottomrule
# \end{tabular}

# %%
dddf = Fdf[Fdf["participation"] == 1].groupby(["ageGroup","skillLevel"])["investmentAmount"].describe()[["count","mean", "std", "50%", "25%", "75%"]]
print(dddf.to_latex())
# Out:
# \begin{tabular}{llrrrrrr}
# \toprule
#       &     &   count &  mean &    std &   50\% &   25\% &    75\% \\
# ageGroup & skillLevel &         &       &        &       &       &        \\
# \midrule
# 20-40 & High & 2671.00 & 28.73 &  52.29 &  8.71 &  2.35 &  29.39 \\
#       & Low &   74.00 & 33.23 &  63.16 &  5.44 &  1.66 &  36.65 \\
# 40-60 & High & 3085.00 & 53.71 &  75.40 & 23.48 &  5.64 &  66.06 \\
#       & Low &  129.00 & 42.03 &  84.66 & 11.74 &  3.32 &  33.18 \\
# 60-80 & High & 1409.00 & 91.91 & 102.55 & 54.55 & 11.93 & 136.36 \\
#       & Low &  158.00 & 68.66 &  90.91 & 31.10 &  6.98 &  93.45 \\
# \bottomrule
# \end{tabular}

# %%
def latexSummaryTable(var, df = Fdf):
    ddf = Fdf.groupby(["industry"])[var].describe()[["count","mean", "std", "50%", "25%", "75%"]]
    print(ddf.to_latex())
    ddf = Fdf.groupby(["ageGroup","industry"])[var].describe()[["count","mean", "std", "50%", "25%", "75%"]]
    print(ddf.to_latex())
    ddf = Fdf.groupby(["skillLevel"])[var].describe()[["count","mean", "std", "50%", "25%", "75%"]]
    print(ddf.to_latex())
    ddf = Fdf.groupby(["ageGroup","skillLevel"])[var].describe()[["count","mean", "std", "50%", "25%", "75%"]]
    print(ddf.to_latex())

# %%
latexSummaryTable("liquidWealth")
# Out:
# \begin{tabular}{lrrrrrr}
# \toprule
# {} &    count &  mean &   std &  50\% &  25\% &   75\% \\
# industry    &          &       &       &      &      &       \\
# \midrule
# finance     &  1517.00 & 12.65 & 26.21 & 3.00 & 0.42 & 11.06 \\
# noneFinance & 53911.00 &  8.39 & 20.82 & 1.19 & 0.00 &  6.50 \\
# \bottomrule
# \end{tabular}
#
# \begin{tabular}{llrrrrrr}
# \toprule
#       &             &    count &  mean &   std &  50\% &  25\% &   75\% \\
# ageGroup & industry &          &       &       &      &      &       \\
# \midrule
# 20-40 & finance &   663.00 & 10.58 & 24.89 & 2.35 & 0.40 &  8.09 \\
#       & noneFinance & 24406.00 &  5.18 & 13.39 & 0.88 & 0.00 &  4.42 \\
# 40-60 & finance &   630.00 & 13.96 & 26.84 & 3.42 & 0.47 & 14.01 \\
#       & noneFinance & 21509.00 &  9.06 & 21.60 & 1.36 & 0.00 &  7.57 \\
# 60-80 & finance &   224.00 & 15.12 & 27.84 & 3.87 & 0.46 & 17.57 \\
#       & noneFinance &  7996.00 & 16.39 & 31.99 & 2.82 & 0.06 & 15.98 \\
# \bottomrule
# \end{tabular}
#
# \begin{tabular}{lrrrrrr}
# \toprule
# {} &    count &  mean &   std &  50\% &  25\% &  75\% \\
# skillLevel &          &       &       &      &      &      \\
# \midrule
# High       & 45868.00 &  9.58 & 22.16 & 1.88 & 0.05 & 8.26 \\
# Low        &  9560.00 &  3.32 & 12.91 & 0.00 & 0.00 & 1.11 \\
# \bottomrule
# \end{tabular}
#
# \begin{tabular}{llrrrrrr}
# \toprule
#       &     &    count &  mean &   std &  50\% &  25\% &   75\% \\
# ageGroup & skillLevel &          &       &       &      &      &       \\
# \midrule
# 20-40 & High & 21287.00 &  6.01 & 14.70 & 1.33 & 0.01 &  5.30 \\
#       & Low &  3782.00 &  1.43 &  6.12 & 0.00 & 0.00 &  0.55 \\
# 40-60 & High & 18476.00 & 10.49 & 23.15 & 2.18 & 0.04 &  9.39 \\
#       & Low &  3663.00 &  2.66 & 10.60 & 0.00 & 0.00 &  1.19 \\
# 60-80 & High &  6105.00 & 19.31 & 34.27 & 4.55 & 0.50 & 20.64 \\
#       & Low &  2115.00 &  7.83 & 21.54 & 0.22 & 0.00 &  4.00 \\
# \bottomrule
# \end{tabular}

# %%
latexSummaryTable("laborIncome")
# Out:
# \begin{tabular}{lrrrrrr}
# \toprule
# {} &    count &  mean &   std &   50\% &   25\% &   75\% \\
# industry    &          &       &       &       &       &       \\
# \midrule
# finance     &  1517.00 & 49.99 & 45.53 & 37.20 & 17.42 & 70.14 \\
# noneFinance & 53911.00 & 42.60 & 38.82 & 33.41 & 12.61 & 63.07 \\
# \bottomrule
# \end{tabular}
#
# \begin{tabular}{llrrrrrr}
# \toprule
#       &             &    count &  mean &   std &   50\% &   25\% &   75\% \\
# ageGroup & industry &          &       &       &       &       &       \\
# \midrule
# 20-40 & finance &   663.00 & 56.22 & 43.02 & 43.64 & 25.12 & 78.19 \\
#       & noneFinance & 24406.00 & 43.74 & 34.99 & 35.70 & 18.30 & 61.06 \\
# 40-60 & finance &   630.00 & 55.73 & 47.81 & 42.26 & 22.28 & 78.86 \\
#       & noneFinance & 21509.00 & 50.43 & 41.98 & 41.16 & 18.20 & 75.01 \\
# 60-80 & finance &   224.00 & 15.37 & 27.24 &  1.56 &  0.00 & 24.86 \\
#       & noneFinance &  7996.00 & 18.06 & 30.23 &  0.00 &  0.00 & 26.42 \\
# \bottomrule
# \end{tabular}
#
# \begin{tabular}{lrrrrrr}
# \toprule
# {} &    count &  mean &   std &   50\% &   25\% &   75\% \\
# skillLevel &          &       &       &       &       &       \\
# \midrule
# High       & 45868.00 & 47.06 & 40.03 & 38.33 & 16.61 & 68.94 \\
# Low        &  9560.00 & 22.38 & 25.40 & 15.91 &  0.00 & 33.80 \\
# \bottomrule
# \end{tabular}
#
# \begin{tabular}{llrrrrrr}
# \toprule
#       &     &    count &  mean &   std &   50\% &   25\% &   75\% \\
# ageGroup & skillLevel &          &       &       &       &       &       \\
# \midrule
# 20-40 & High & 21287.00 & 47.31 & 35.94 & 39.24 & 21.36 & 65.76 \\
#       & Low &  3782.00 & 25.82 & 24.23 & 20.00 &  8.27 & 36.39 \\
# 40-60 & High & 18476.00 & 55.21 & 43.06 & 47.25 & 22.22 & 81.14 \\
#       & Low &  3663.00 & 27.22 & 27.21 & 22.30 &  4.21 & 39.33 \\
# 60-80 & High &  6105.00 & 21.50 & 32.69 &  3.85 &  0.00 & 33.20 \\
#       & Low &  2115.00 &  7.82 & 17.64 &  0.00 &  0.00 &  5.87 \\
# \bottomrule
# \end{tabular}

# %%
latexSummaryTable("wealthWithHomeEquity")
# Out:
# \begin{tabular}{lrrrrrr}
# \toprule
# {} &    count &   mean &    std &   50\% &  25\% &    75\% \\
# industry    &          &        &        &       &      &        \\
# \midrule
# finance     &  1517.00 & 115.21 & 168.51 & 55.30 & 3.62 & 160.82 \\
# noneFinance & 53911.00 &  90.80 & 158.69 & 26.65 & 1.11 & 117.26 \\
# \bottomrule
# \end{tabular}
#
# \begin{tabular}{llrrrrrr}
# \toprule
#       &             &    count &   mean &    std &    50\% &   25\% &    75\% \\
# ageGroup & industry &          &        &        &        &       &        \\
# \midrule
# 20-40 & finance &   663.00 &  64.25 & 120.08 &  18.51 &  0.00 &  85.40 \\
#       & noneFinance & 24406.00 &  40.10 & 104.13 &   8.22 &  0.00 &  45.90 \\
# 40-60 & finance &   630.00 & 141.93 & 181.91 &  79.87 & 11.85 & 201.71 \\
#       & noneFinance & 21509.00 & 114.76 & 169.35 &  50.88 &  4.70 & 159.09 \\
# 60-80 & finance &   224.00 & 190.89 & 203.50 & 120.95 & 23.87 & 295.01 \\
#       & noneFinance &  7996.00 & 181.09 & 204.96 & 107.15 & 22.68 & 274.77 \\
# \bottomrule
# \end{tabular}
#
# \begin{tabular}{lrrrrrr}
# \toprule
# {} &    count &   mean &    std &   50\% &  25\% &    75\% \\
# skillLevel &          &        &        &       &      &        \\
# \midrule
# High       & 45868.00 & 101.21 & 167.24 & 34.40 & 2.10 & 136.82 \\
# Low        &  9560.00 &  44.70 &  98.82 &  7.52 & 0.00 &  52.34 \\
# \bottomrule
# \end{tabular}
#
# \begin{tabular}{llrrrrrr}
# \toprule
#       &     &    count &   mean &    std &    50\% &   25\% &    75\% \\
# ageGroup & skillLevel &          &        &        &        &       &        \\
# \midrule
# 20-40 & High & 21287.00 &  44.97 & 109.83 &  10.52 &  0.00 &  54.09 \\
#       & Low &  3782.00 &  16.89 &  63.52 &   2.42 &  0.00 &  15.44 \\
# 40-60 & High & 18476.00 & 129.25 & 177.81 &  64.00 &  8.26 & 187.07 \\
#       & Low &  3663.00 &  46.35 &  94.90 &  12.28 &  0.00 &  62.83 \\
# 60-80 & High &  6105.00 & 212.47 & 215.93 & 148.35 & 41.91 & 323.22 \\
#       & Low &  2115.00 &  91.56 & 133.25 &  42.27 &  2.12 & 117.09 \\
# \bottomrule
# \end{tabular}

# %%
Fdf.head()
# Out:
#    familyID  year  composition  headCount  ageHead  liquidWealth  laborIncome  \
# 0         3  1999            2          1       76          2.35         0.00
# 1         2  1999            0          4       47          0.00        26.14
# 2      6129  1999            3          1       45          8.81         0.00
# 3      6944  1999            0          2       39         14.09        35.23
# 4      3818  1999            4          4       34          0.00        48.85
#
#    costPerPerson  totalExpense  participation  ...  maritalStatus  \
# 0           7.30          7.30              0  ...        Widowed
# 1           4.17         16.68              1  ...        Married
# 2          16.70         16.70              1  ...       Divorced
# 3          10.29         20.58              0  ...       Divorced
# 4           4.45         17.80              0  ...        Married
#
#    employmentStatus   education   race     industry ownership skillLevel  \
# 0           retired  highSchool  White  noneFinance     owner        Low
# 1          employed  highSchool  White  noneFinance     owner        Low
# 2          employed     college  White      finance     owner       High
# 3          employed     college  White  noneFinance     owner       High
# 4          employed  highSchool  White  noneFinance     owner        Low
#
#   financeExperience ageGroup decadeGroup
# 0                No    60-80       1990s
# 1                No    40-60       1990s
# 2               Yes    40-60       1990s
# 3                No    20-40       1990s
# 4                No    20-40       1990s
#
# [5 rows x 25 columns]

# %%
Fdf["stockInvestmentRatio"] = Fdf.investmentAmount/Fdf.wealthWithoutHomeEquity
Fdf.loc[-((Fdf["stockInvestmentRatio"] >= 0)&(Fdf["stockInvestmentRatio"] <= 1)), "stockInvestmentRatio"] = 0

# %%
categoricalValue = ["participation","skillLevel","financeExperience","employmentStatus","ownership"]
realValue = ["investmentAmount", "wealthWithHomeEquity", "stockInvestmentRatio", "laborIncome"]

# %%
Fdf[categoricalValue].astype('object').describe()
# Out:
#         participation skillLevel financeExperience employmentStatus ownership
# count           55428      55428             55428            55428     55428
# unique              2          2                 2                3         2
# top                 0       High                No         employed     owner
# freq            47902      45868             53911            41849     31761

# %%
dddf = Fdf[realValue].describe().T[["count","mean", "std", "50%", "25%", "75%"]]
print(dddf.to_latex())
# Out:
# \begin{tabular}{lrrrrrr}
# \toprule
# {} &    count &  mean &    std &   50\% &   25\% &    75\% \\
# \midrule
# investmentAmount     & 55428.00 &  7.05 &  33.84 &  0.00 &  0.00 &   0.00 \\
# wealthWithHomeEquity & 55428.00 & 91.46 & 159.02 & 27.25 &  1.17 & 118.48 \\
# stockInvestmentRatio & 55428.00 &  0.04 &   0.14 &  0.00 &  0.00 &   0.00 \\
# laborIncome          & 55428.00 & 42.80 &  39.04 & 33.64 & 12.70 &  63.41 \\
# \bottomrule
# \end{tabular}

# %%
Fdf[]

# %%
Fdf.shape
# Out:
# (55428, 25)

# %%
Fdf.to_csv("familyData.csv")

# %%
plt.title("Participation ratio over different edcucation backgrounds")
Fdf.loc[Fdf["education"]=="middleSchool", "education"] = "highSchool"
Fdf.groupby("education").participation.mean().reindex(["highSchool", "college", "postGraduate"]).plot.bar(color = "blue",rot=0)
savefig('educationParticipation.jpg')

# %%
Fdf.loc[Fdf["employmentStatus"]=="Working", "employmentStatus"] = "employed"
plt.title("Participation ratio over different employment status")
Fdf.groupby("employmentStatus").participation.mean().reindex(["unemployed", "employed", "retired"]).plot.bar(color = "blue",rot=0)
savefig('employmentParticipation.jpg')

# %%
plt.title("Participation ratio over different employment industries")
Fdf.groupby("industry").participation.mean().plot.bar(color = "blue",rot=0)
savefig('industryParticipation.jpg')

# %%
plt.title("Participation ratio over different age groups")
Fdf.groupby("ageGroup").participation.mean().plot.bar(color = "blue",rot=0)
savefig('ageParticipation.jpg')

# %%
plt.title("Participation ratio over housing status")
Fdf.groupby("ownership").participation.mean().plot.bar(color = "blue",rot=0)
savefig('ownership.jpg')

# %%
plt.title("Participation ratio over different years")
Fdf.groupby("year").participation.mean().plot.bar(color = "blue",rot=0)
savefig('year.jpg')

# %%
participationYear = pd.DataFrame(columns = ["Year", "participationRatio"])

# %%
participationYear["Year"] = years

# %%
participationYear["participationRatio"] = Fdf.groupby("year")["participation"].mean().values

# %%
participationYear = participationYear.set_index("Year")

# %%
print(participationYear.T.to_latex())
# Out:
# \begin{tabular}{lrrrrrrrrrr}
# \toprule
# Year &  1999 &  2001 &  2003 &  2005 &  2007 &  2009 &  2011 &  2013 &  2015 &  2017 \\
# \midrule
# participationRatio &  0.20 &  0.20 &  0.18 &  0.15 &  0.15 &  0.13 &  0.10 &  0.10 &  0.08 &  0.09 \\
# \bottomrule
# \end{tabular}
